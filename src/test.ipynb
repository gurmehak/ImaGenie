# %% [markdown]
# Dummy notebook to read in image and perform functions

# %%
import numpy as np
from matplotlib import image
import matplotlib.pyplot as plt

# %%
img=plt.imread('testimage.png')

# %%
plt.imshow(img)

# %% [markdown]
# Add functions below
